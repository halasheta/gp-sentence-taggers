# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Accruracy of the Models Evaluated
MASKED_res = 0.07482993197278912
MASKED_resGarden = 0.033112582781456956

lr01_pd10_res = 0.3045
lr001_pd10_res = 0.3591
lr0001_pd10_res = 0.1773
lr01_pd10_resGarden = 0.2476
lr001_pd10_resGarden = 0.3095
lr0001_pd10_resGarden = 0.2000

lr01_pd100_res = 0.9300
lr001_pd100_res = 0.9436
lr0001_pd100_res = 0.9323
lr01_pd100_resGarden = 0.9257
lr001_pd100_resGarden = 0.9424
lr0001_pd100_resGarden = 0.9310

lr01_pd50_res = 0.8600
lr001_pd50_res = 0.8845
lr0001_pd50_res = 0.8818
lr01_pd50_resGarden = 0.8524
lr001_pd50_resGarden = 0.8838
lr0001_pd50_resGarden = 0.8781

# %%
# Accuracy of the Predictions

MASKED_res = 0.07482993197278912
MASKED_resGarden = 0.033112582781456956

lr01_pd10_res = 0.08636363636363636
lr001_pd10_res = 0.12272727272727273
lr0001_pd10_res = 0.17727272727272728
lr01_pd10_resGarden = 0.06666666666666667
lr001_pd10_resGarden = 0.11428571428571428
lr0001_pd10_resGarden = 0.2

lr01_pd100_res = 0.005909090909090909
lr001_pd100_res = 0.019090909090909092
lr0001_pd100_res = 0.0027272727272727275
lr01_pd100_resGarden = 0.0033333333333333335
lr001_pd100_resGarden = 0.02
lr0001_pd100_resGarden = 0.002857142857142857

lr01_pd50_res = 0.012727272727272728
lr001_pd50_res = 0.03272727272727273
lr0001_pd50_res = 0.025454545454545455
lr01_pd50_resGarden = 0.006666666666666667
lr001_pd50_resGarden = 0.03619047619047619
lr0001_pd50_resGarden = 0.0304761904761904761

# %%
fig = plt.subplots(figsize =(10, 8))


y10 = [lr01_pd10_res, lr001_pd10_res, lr0001_pd10_res]

y10Garden = [lr01_pd10_resGarden, lr001_pd10_resGarden, lr0001_pd10_resGarden]

y50 = [lr01_pd50_res, lr001_pd50_res, lr0001_pd50_res]

y50Garden = [lr01_pd50_resGarden, lr001_pd50_resGarden, lr0001_pd50_resGarden]

y100 = [lr01_pd100_res, lr001_pd100_res, lr0001_pd100_res]

y100Garden = [lr01_pd100_resGarden, lr001_pd100_resGarden, lr0001_pd100_resGarden]

X = np.arange(len(y10))

barWidth = 0.1

plt.bar(X + 0.00, y10, color = 'lightpink', edgecolor ='grey', width = barWidth, label = 'NS 10')
plt.bar(X + 0.1, y50, color = 'lightblue', edgecolor ='grey', width = barWidth, label = 'NS 50')
plt.bar(X + 0.2, y100, color = 'springgreen', edgecolor ='grey', width = barWidth, label = 'NS 100')
plt.bar(X + 0.3, y10Garden, color = 'yellow', edgecolor ='grey', width = barWidth, label = 'GS 10')
plt.bar(X + 0.4, y50Garden, color = 'violet', edgecolor ='grey', width = barWidth, label = 'GS 50')
plt.bar(X + 0.5, y100Garden, color = 'darkorange', edgecolor ='grey', width = barWidth, label = 'GS 100')

plt.xlabel('Learning Rate', fontsize = 10)
plt.ylabel('Accuracy', fontsize = 10)

plt.xticks([r + 0.2 for r in range(len(y10) + 1)],
        ['0.1', '0.01', '0.001', ''])
plt.yticks(np.arange(0, 1, 0.1))

plt.title('Accuracy of LSTM Model Evaluation on Normal and Garden Path Sentences', fontsize = 12)

plt.legend()
plt.show()

# %%
# fig = plt.subplots(figsize =(12, 8))


y10 = [lr01_pd10_res, lr001_pd10_res, lr0001_pd10_res]

y10Garden = [lr01_pd10_resGarden, lr001_pd10_resGarden, lr0001_pd10_resGarden]

y50 = [lr01_pd50_res, lr001_pd50_res, lr0001_pd50_res]

y50Garden = [lr01_pd50_resGarden, lr001_pd50_resGarden, lr0001_pd50_resGarden]

y100 = [lr01_pd100_res, lr001_pd100_res, lr0001_pd100_res]

y100Garden = [lr01_pd100_resGarden, lr001_pd100_resGarden, lr0001_pd100_resGarden]

X = np.arange(len(y10))

barWidth = 0.1

plt.bar(X + 0.00, y10, color = 'lightpink', edgecolor ='grey', width = barWidth, label = 'NS 10')
plt.bar(X + 0.1, y50, color = 'lightblue', edgecolor ='grey', width = barWidth, label = 'NS 50')
plt.bar(X + 0.2, y100, color = 'springgreen', edgecolor ='grey', width = barWidth, label = 'NS 100')
plt.bar(X + 0.3, y10Garden, color = 'yellow', edgecolor ='grey', width = barWidth, label = 'GS 10')
plt.bar(X + 0.4, y50Garden, color = 'violet', edgecolor ='grey', width = barWidth, label = 'GS 50')
plt.bar(X + 0.5, y100Garden, color = 'darkorange', edgecolor ='grey', width = barWidth, label = 'GS 100')

plt.xlabel('Learning Rate', fontsize = 10)
plt.ylabel('Accuracy', fontsize = 10)

plt.xticks([r + 0.2 for r in range(len(y10) + 1)],
        ['0.1', '0.01', '0.001', ''])
plt.yticks(np.arange(0, 0.3, 0.05))

plt.title('Accuracy of LSTM Model Prediction on Normal and Garden Path Sentences', fontsize = 12)

plt.legend()
plt.show()

# %%
y100 = [lr0001_pd100_res]
y100Garden = [lr0001_pd100_resGarden]

MASKED = [MASKED_res]
MASKEDGarden = [MASKED_resGarden]

bar_labels = ('Masked False NS', 'Masked False GS', 'Masked True NS', 'Masked True GS')

X = np.arange(len(y100))

barWidth = 0.3

plt.bar(X, y100, color = 'springgreen', edgecolor ='grey', width = barWidth, label = 'Masked False 100')
plt.bar(X + 1, y100Garden, color = 'yellow', edgecolor ='grey', width = barWidth, label = 'Masked False 100')
plt.bar(X + 2, MASKED, color = 'pink', edgecolor ='grey', width = barWidth, label = 'Masked True 100')
plt.bar(X + 3, MASKEDGarden, color = 'lightblue', edgecolor ='grey', width = barWidth, label = 'Masked True 100')

plt.ylabel('Accuracy', fontsize = 10)
plt.xticks(np.arange(len(bar_labels)), bar_labels, color='black', rotation=0, fontsize='10', horizontalalignment='center')
plt.yticks(np.arange(0, 0.0055, 0.001))

plt.title('Accuracy of LSTM Model Prediction on Normal and Garden Path Sentences with Padding 100', fontsize = 12)

# plt.legend()
plt.show()

# %%
y100 = [lr0001_pd100_res]
y100Garden = [lr0001_pd100_resGarden]

MASKED = [MASKED_res]
MASKEDGarden = [MASKED_resGarden]

bar_labels = ('Masked False NS', 'Masked False GS', 'Masked True NS', 'Masked True GS')

X = np.arange(len(y100))

barWidth = 0.3

plt.bar(X, y100, color = 'springgreen', edgecolor ='grey', width = barWidth, label = 'Masked False 100')
plt.bar(X + 1, y100Garden, color = 'yellow', edgecolor ='grey', width = barWidth, label = 'Masked False 100')
plt.bar(X + 2, MASKED, color = 'pink', edgecolor ='grey', width = barWidth, label = 'Masked True 100')
plt.bar(X + 3, MASKEDGarden, color = 'lightblue', edgecolor ='grey', width = barWidth, label = 'Masked True 100')

plt.ylabel('Accuracy', fontsize = 10)

plt.yticks(np.arange(0, 1, 0.1))
plt.xticks(np.arange(len(bar_labels)), bar_labels, color='black', rotation=0, fontsize='10', horizontalalignment='center')

plt.title('Accuracy of LSTM Model Evaluation on Normal and Garden Path Sentences with Padding 100', fontsize = 12)

# plt.legend()
plt.show()

# %%
y10 = [lr0001_pd10_res]
y100Garden = [lr0001_pd10_resGarden]

MASKED = [MASKED_res]
MASKEDGarden = [MASKED_resGarden]

bar_labels = ('Masked False NS', 'Masked False GS', 'Masked True NS', 'Masked True GS')

X = np.arange(len(y10))

barWidth = 0.3

plt.bar(X, y10, color = 'springgreen', edgecolor ='grey', width = barWidth, label = 'Masked False')
plt.bar(X + 1, y100Garden, color = 'yellow', edgecolor ='grey', width = barWidth, label = 'Masked False')
plt.bar(X + 2, MASKED, color = 'pink', edgecolor ='grey', width = barWidth, label = 'Masked True 100')
plt.bar(X + 3, MASKEDGarden, color = 'lightblue', edgecolor ='grey', width = barWidth, label = 'Masked True')

plt.ylabel('Accuracy', fontsize = 10)

plt.yticks(np.arange(0, .3, 0.05))
plt.xticks(np.arange(len(bar_labels)), bar_labels, color='black', rotation=0, fontsize='10', horizontalalignment='center')

plt.title('Accuracy of LSTM Model Evaluation on Normal and Garden Path Sentences with Padding 10', fontsize = 12)

# plt.legend()
plt.show()

# %%
y10 = [lr0001_pd10_res]
y100Garden = [lr0001_pd10_resGarden]

MASKED = [MASKED_res]
MASKEDGarden = [MASKED_resGarden]

bar_labels = ('Masked False NS', 'Masked False GS', 'Masked True NS', 'Masked True GS')

X = np.arange(len(y10))

barWidth = 0.3

plt.bar(X, y10, color = 'springgreen', edgecolor ='grey', width = barWidth, label = 'Masked False')
plt.bar(X + 1, y100Garden, color = 'yellow', edgecolor ='grey', width = barWidth, label = 'Masked False')
plt.bar(X + 2, MASKED, color = 'pink', edgecolor ='grey', width = barWidth, label = 'Masked True 100')
plt.bar(X + 3, MASKEDGarden, color = 'lightblue', edgecolor ='grey', width = barWidth, label = 'Masked True')

plt.ylabel('Accuracy', fontsize = 10)

plt.yticks(np.arange(0, .3, 0.05))
plt.xticks(np.arange(len(bar_labels)), bar_labels, color='black', rotation=0, fontsize='10', horizontalalignment='center')

plt.title('Accuracy of LSTM Model Prediction on Normal and Garden Path Sentences with Padding 10', fontsize = 12)

# plt.legend()
plt.show()
